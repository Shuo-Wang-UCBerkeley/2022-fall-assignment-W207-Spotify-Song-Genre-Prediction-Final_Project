# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_df = pd.read_csv("genres_v2.csv", low_memory=False)

# %%
raw_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# 3          0.000000    0.1140   0.1750  ...  0VSXnJqQkwuH2ei1nOQ1nu
# 4          0.000000    0.1660   0.5910  ...  4jCeguq9rMTlbMmPHuO7S3
#
#                                     uri  \
# 0  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 1  spotify:track:7pgJBLVz5VmnL7uGHmRj6p
# 2  spotify:track:0vSWgAlfpye0WCGeNmuNhy
# 3  spotify:track:0VSXnJqQkwuH2ei1nOQ1nu
# 4  spotify:track:4jCeguq9rMTlbMmPHuO7S3
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 1  https://api.spotify.com/v1/tracks/7pgJBLVz5Vmn...
# 2  https://api.spotify.com/v1/tracks/0vSWgAlfpye0...
# 3  https://api.spotify.com/v1/tracks/0VSXnJqQkwuH...
# 4  https://api.spotify.com/v1/tracks/4jCeguq9rMTl...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 1  https://api.spotify.com/v1/audio-analysis/7pgJ...      224427
# 2  https://api.spotify.com/v1/audio-analysis/0vSW...       98821
# 3  https://api.spotify.com/v1/audio-analysis/0VSX...      123661
# 4  https://api.spotify.com/v1/audio-analysis/4jCe...      123298
#
#   time_signature      genre                                      song_name  \
# 0              4  Dark Trap                            Mercury: Retrograde
# 1              4  Dark Trap                                      Pathology
# 2              4  Dark Trap                                       Symbiote
# 3              3  Dark Trap  ProductOfDrugs (Prod. The Virus and Antidote)
# 4              4  Dark Trap                                          Venom
#
#   Unnamed: 0 title
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
#
# [5 rows x 22 columns]

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42305 entries, 0 to 42304
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      42305 non-null  float64
#  1   energy            42305 non-null  float64
#  2   key               42305 non-null  int64
#  3   loudness          42305 non-null  float64
#  4   mode              42305 non-null  int64
#  5   speechiness       42305 non-null  float64
#  6   acousticness      42305 non-null  float64
#  7   instrumentalness  42305 non-null  float64
#  8   liveness          42305 non-null  float64
#  9   valence           42305 non-null  float64
#  10  tempo             42305 non-null  float64
#  11  type              42305 non-null  object
#  12  id                42305 non-null  object
#  13  uri               42305 non-null  object
#  14  track_href        42305 non-null  object
#  15  analysis_url      42305 non-null  object
#  16  duration_ms       42305 non-null  int64
#  17  time_signature    42305 non-null  int64
#  18  genre             42305 non-null  object
#  19  song_name         21519 non-null  object
#  20  Unnamed: 0        20780 non-null  float64
#  21  title             20780 non-null  object
# dtypes: float64(10), int64(4), object(8)
# memory usage: 7.1+ MB

# %%
print("-----------Columns with missing data ------------")
for col in raw_df.columns:
    pct_missing = raw_df[col].isnull().sum()/len(raw_df[col])*100
    if pct_missing > 0:
        print("Column:", col, "       % of records missing:", "{0:.2f}%".format(pct_missing))
# Out:
# -----------Columns with missing data ------------
# Column: song_name        % of records missing: 49.13%
# Column: Unnamed: 0        % of records missing: 50.88%
# Column: title        % of records missing: 50.88%

# %%
df = raw_df.drop(['Unnamed: 0','title'], axis=1)
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.013400    0.0556   0.3890  156.985  audio_features
# 1          0.000000    0.1180   0.1240  115.080  audio_features
# 2          0.000004    0.3720   0.0391  218.050  audio_features
# 3          0.000000    0.1140   0.1750  186.948  audio_features
# 4          0.000000    0.1660   0.5910  147.988  audio_features
#
#                        id                                   uri  \
# 0  2Vc6NJ9PW9gD9q343XFRKx  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 1  7pgJBLVz5VmnL7uGHmRj6p  spotify:track:7pgJBLVz5VmnL7uGHmRj6p
# 2  0vSWgAlfpye0WCGeNmuNhy  spotify:track:0vSWgAlfpye0WCGeNmuNhy
# 3  0VSXnJqQkwuH2ei1nOQ1nu  spotify:track:0VSXnJqQkwuH2ei1nOQ1nu
# 4  4jCeguq9rMTlbMmPHuO7S3  spotify:track:4jCeguq9rMTlbMmPHuO7S3
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 1  https://api.spotify.com/v1/tracks/7pgJBLVz5Vmn...
# 2  https://api.spotify.com/v1/tracks/0vSWgAlfpye0...
# 3  https://api.spotify.com/v1/tracks/0VSXnJqQkwuH...
# 4  https://api.spotify.com/v1/tracks/4jCeguq9rMTl...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Vc6...       124539
# 1  https://api.spotify.com/v1/audio-analysis/7pgJ...       224427
# 2  https://api.spotify.com/v1/audio-analysis/0vSW...        98821
# 3  https://api.spotify.com/v1/audio-analysis/0VSX...       123661
# 4  https://api.spotify.com/v1/audio-analysis/4jCe...       123298
#
#    time_signature      genre                                      song_name
# 0               4  Dark Trap                            Mercury: Retrograde
# 1               4  Dark Trap                                      Pathology
# 2               4  Dark Trap                                       Symbiote
# 3               3  Dark Trap  ProductOfDrugs (Prod. The Virus and Antidote)
# 4               4  Dark Trap                                          Venom

# %%
print("---------Unique values per Column----------")
df.nunique().sort_values(ascending=False)
# Out:
# ---------Unique values per Column----------
# id                  35877
# analysis_url        35877
# track_href          35877
# uri                 35877
# duration_ms         26261
# tempo               15606
# song_name           15439
# loudness            11654
# instrumentalness     4757
# acousticness         4602
# liveness             1695
# valence              1674
# speechiness          1447
# energy                917
# danceability          890
# genre                  15
# key                    12
# time_signature          4
# mode                    2
# type                    1
# dtype: int64

# %%
df.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# genre                object
# song_name            object
# dtype: object

# %%
numeric_cols = list(df.select_dtypes(include='number').columns)
numeric_cols
# Out:
# ['danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms',
#  'time_signature']

# %%
print("--------Types of Columns--------")
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numeric_cols = list(df.select_dtypes(include=numerics).columns)

categorical_cols = list(df.select_dtypes(exclude=numerics).columns)

#move some numeric to categorical
switch_cols = ['mode', 'key']
numeric_cols = [i for i in numeric_cols if i not in (switch_cols)]
categorical_cols.extend(switch_cols)


print(len(numeric_cols), "numeric cols:", numeric_cols)
print()
print(len(categorical_cols),"categorical cols:", categorical_cols)
# Out:
# --------Types of Columns--------
# 11 numeric cols: ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']
#
# 9 categorical cols: ['type', 'id', 'uri', 'track_href', 'analysis_url', 'genre', 'song_name', 'mode', 'key']

# %%
print("----------Numeric Column Summary Stats-------------")
df[numeric_cols].describe().transpose()
# Out:
# ----------Numeric Column Summary Stats-------------
#                     count           mean            std           min  \
# danceability      42305.0       0.639364       0.156617      0.065100
# energy            42305.0       0.762516       0.183823      0.000243
# loudness          42305.0      -6.465442       2.941165    -33.357000
# speechiness       42305.0       0.136561       0.126168      0.022700
# acousticness      42305.0       0.096160       0.170827      0.000001
# instrumentalness  42305.0       0.283048       0.370791      0.000000
# liveness          42305.0       0.214079       0.175576      0.010700
# valence           42305.0       0.357101       0.233200      0.018700
# tempo             42305.0     147.474056      23.844623     57.967000
# duration_ms       42305.0  250865.846685  102957.713571  25600.000000
# time_signature    42305.0       3.972580       0.268342      1.000000
#
#                            25%           50%         75%         max
# danceability           0.52400       0.64600       0.766       0.988
# energy                 0.63200       0.80300       0.923       1.000
# loudness              -8.16100      -6.23400      -4.513       3.148
# speechiness            0.04910       0.07550       0.193       0.946
# acousticness           0.00173       0.01640       0.107       0.988
# instrumentalness       0.00000       0.00594       0.722       0.989
# liveness               0.09960       0.13500       0.294       0.988
# valence                0.16100       0.32200       0.522       0.988
# tempo                129.93100     144.97300     161.464     220.290
# duration_ms       179840.00000  224760.00000  301133.000  913052.000
# time_signature         4.00000       4.00000       4.000       5.000

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.gca()
df[numeric_cols].hist(ax = ax, bins=10, color ='b')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f043243a4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0432080a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f04324d7f10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0432289510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f04328aa9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0432846a10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0432b64dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f042e852210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f042e852250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f042e807810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f042e781150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f04327b9f90>]],
#       dtype=object)

# %%
print('Unique Categorical Values')
print('-----------------')
df[categorical_cols].nunique()
# Out:
# Unique Categorical Values
# -----------------
# type                1
# id              35877
# uri             35877
# track_href      35877
# analysis_url    35877
# genre              15
# song_name       15439
# mode                2
# key                12
# dtype: int64

# %%
df['genre'].value_counts().plot( kind='bar', title='record count by genre')
fig.tight_layout(pad=1.0)
plt.show()

# %%
fig, axs = plt.subplots(1,2, figsize=(15, 5))
axs = axs.ravel()
i=0
for cat in ['key','mode']:
    df[cat].value_counts().plot(ax=axs[i], kind='bar', title='record count by ' + cat)
    i+=1
fig.tight_layout(pad=1.0)
plt.show()

# %%
correlation_mat =df[numeric_cols].corr()
fig, ax = plt.subplots(figsize=(10,10))   
sns.heatmap(correlation_mat, annot = True, ax=ax)
# Out:
# <AxesSubplot:>

# %%
raw_df['genre'].value_counts()
# Out:
# Underground Rap    5875
# Dark Trap          4578
# Hiphop             3028
# trance             2999
# trap               2987
# techhouse          2975
# dnb                2966
# psytrance          2961
# techno             2956
# hardstyle          2936
# RnB                2099
# Trap Metal         1956
# Rap                1848
# Emo                1680
# Pop                 461
# Name: genre, dtype: int64

# %%
one_hot_encoded_df = pd.get_dummies(df['genre'])
genre_one_hot_encoded = list(one_hot_encoded_df.columns)

df[genre_one_hot_encoded] = one_hot_encoded_df

# %%
ohe_genre_cols = list(df[genre_one_hot_encoded].columns)
fig, ax = plt.subplots(figsize=(10,10))  
feature_target_corr_df = df[numeric_cols+ohe_genre_cols].corr()[numeric_cols].filter(items=ohe_genre_cols, axis=0)
sns.heatmap(feature_target_corr_df, annot=True, ax=ax, center=0)

# %%
for genre in genre_one_hot_encoded:
    numeric_plus_target = numeric_cols + [genre]

    correlation_mat =df[numeric_plus_target].corr()
    fig, ax = plt.subplots(figsize=(10,10))   
    sns.heatmap(correlation_mat, annot = True, ax=ax)

# %%
# Outliers:


# Following 1.5Q1, Q3 rule for outliers
q1 = df[numeric_cols].describe().iloc[4,:]

q3 = df[numeric_cols].describe().iloc[6,:]

outliers_df = pd.DataFrame(index=df.index)

for column in numeric_cols:
    print(column)
    
    outliers_df[column] = df[column].loc[(df[column] < 1.5*q1[column]) | (df[column] > 1.5*q3[column])]
# Out:
# danceability
# energy
# loudness
# speechiness
# acousticness
# instrumentalness
# liveness
# valence
# tempo
# duration_ms
# time_signature

# %%
# This is a count of the outliers that we're dealing with

# Out of 

outliers_count = {}

for column in outliers_df.columns:
    outliers_count[column] = round(outliers_df[column].notna().sum()*100/outliers_df.shape[0], 2)

# %%
outliers_count
# Out:
# {'danceability': 79.18,
#  'energy': 83.09,
#  'loudness': 61.6,
#  'speechiness': 63.19,
#  'acousticness': 48.38,
#  'instrumentalness': 0.0,
#  'liveness': 64.34,
#  'valence': 44.24,
#  'tempo': 95.59,
#  'duration_ms': 73.99,
#  'time_signature': 100.0}
